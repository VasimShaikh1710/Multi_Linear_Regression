# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/admin/Desktop/Assignment_DataScience/50_Startups.csv')
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df['State'].value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
co = df.corr()
co
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns

# %%
sns.heatmap(co, xticklabels = co.columns, yticklabels = co.columns,annot = True)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.scatter(df['R&D Spend'],df['Profit'])
plt.xlabel('R&D Spend')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(df['Administration'],df['Profit'])
plt.xlabel('Administration')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(df['Marketing Spend'],df['Profit'])
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(drop = 'first', sparse = False)
df['State'] = ohe.fit_transform(df[['State']])

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10    0.0  192261.83
# 1   162597.70       151377.59        443898.53    0.0  191792.06
# 2   153441.51       101145.55        407934.54    1.0  191050.39
# 3   144372.41       118671.85        383199.62    0.0  182901.99
# 4   142107.34        91391.77        366168.42    1.0  166187.94
# 5   131876.90        99814.71        362861.36    0.0  156991.12
# 6   134615.46       147198.87        127716.82    0.0  156122.51
# 7   130298.13       145530.06        323876.68    1.0  155752.60
# 8   120542.52       148718.95        311613.29    0.0  152211.77
# 9   123334.88       108679.17        304981.62    0.0  149759.96
# 10  101913.08       110594.11        229160.95    1.0  146121.95
# 11  100671.96        91790.61        249744.55    0.0  144259.40
# 12   93863.75       127320.38        249839.44    1.0  141585.52
# ...

# %%
X = df.iloc[:,:4]
X
# Out:
#     R&D Spend  Administration  Marketing Spend  State
# 0   165349.20       136897.80        471784.10    0.0
# 1   162597.70       151377.59        443898.53    0.0
# 2   153441.51       101145.55        407934.54    1.0
# 3   144372.41       118671.85        383199.62    0.0
# 4   142107.34        91391.77        366168.42    1.0
# 5   131876.90        99814.71        362861.36    0.0
# 6   134615.46       147198.87        127716.82    0.0
# 7   130298.13       145530.06        323876.68    1.0
# 8   120542.52       148718.95        311613.29    0.0
# 9   123334.88       108679.17        304981.62    0.0
# 10  101913.08       110594.11        229160.95    1.0
# 11  100671.96        91790.61        249744.55    0.0
# 12   93863.75       127320.38        249839.44    1.0
# 13   91992.39       135495.07        252664.93    0.0
# 14  119943.24       156547.42        256512.92    1.0
# 15  114523.61       122616.84        261776.23    0.0
# ...

# %%
Y = df['Profit']
Y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,train_size = 0.5,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_train = LR.predict(X_train)

# %%
Y_pred_test = LR.predict(X_test)

# %%
from sklearn.metrics import r2_score
R_train = r2_score(Y_pred_train,Y_train)
("Training_Accuracy",R_train)
# Out:
# ('Training_Accuracy', 0.9469293745515576)

# %%
R_test = r2_score(Y_pred_test,Y_test)
("Training_Accuracy",R_test)
# Out:
# ('Training_Accuracy', 0.9361081620623977)
